# %%
import pandas as pd
data_merged = pd.read_csv("pre3.csv")
time_data = pd.read_csv("dataset.csv")
data_merged['INPUT'].dropna(axis = 0)
# Out:
# 0          is there a way to modify the amount of my auto...
# 1                                                     modify
# 2                                                     amount
# 3                                              custom amount
# 4                                                    $185.00
#                                  ...
# 2196863                               i need help logging in
# 2196864                                                   hi
# 2196865                           yes i need to make payment
# 2196866                                       make a payment
# 2196867                                          dont let me
# Name: INPUT, Length: 962008, dtype: object

# %%
data1 = data_merged[0:500000]
data2 = data_merged[500001:1000000]
data3 = data_merged[1000001:1500000]
data4 = data_merged[1500001:]

# %%
data1['DATE_TIME'] = data1.groupby(['IVA_CHAT_ID'])['DATE_TIME'].transform(lambda x : ",".join(map(str, x)))
data1['END_DATE_TIME'] = data1.groupby(['IVA_CHAT_ID'])['END_DATE_TIME'].transform(lambda x : ' '.join(map(str, x)))
data1['CHAT_TYPE'] = data1.groupby(['IVA_CHAT_ID'])['CHAT_TYPE'].transform(lambda x : ' '.join(map(str, x)))
data1['CLIENT_ID'] = data1.groupby(['IVA_CHAT_ID'])['CLIENT_ID'].transform(lambda x : ' '.join(map(str, x)))
data1['IVA_CHAT_REASON'] = data1.groupby(['IVA_CHAT_ID'])['IVA_CHAT_REASON'].transform(lambda x : ' '.join(map(str, x)))
data1['INPUT'] = data1.groupby(['IVA_CHAT_ID'])['INPUT'].transform(lambda x : ' '.join(map(str, x)))
data1['RESPONSE'] = data1.groupby(['IVA_CHAT_ID'])['RESPONSE'].transform(lambda x : ' '.join(map(str, x)))
data1 = data1[['IVA_CHAT_ID','DATE_TIME','END_DATE_TIME','CHAT_TYPE','CLIENT_ID','IVA_CHAT_REASON','INPUT','RESPONSE']] 
data1 = data1.drop_duplicates() 
data2['DATE_TIME'] = data2.groupby(['IVA_CHAT_ID'])['DATE_TIME'].transform(lambda x : ",".join(map(str, x)))
data2['END_DATE_TIME'] = data2.groupby(['IVA_CHAT_ID'])['END_DATE_TIME'].transform(lambda x : ' '.join(map(str, x)))
data2['CHAT_TYPE'] = data2.groupby(['IVA_CHAT_ID'])['CHAT_TYPE'].transform(lambda x : ' '.join(map(str, x)))
data2['CLIENT_ID'] = data2.groupby(['IVA_CHAT_ID'])['CLIENT_ID'].transform(lambda x : ' '.join(map(str, x)))
data2['IVA_CHAT_REASON'] = data2.groupby(['IVA_CHAT_ID'])['IVA_CHAT_REASON'].transform(lambda x : ' '.join(map(str, x)))
data2['INPUT'] = data2.groupby(['IVA_CHAT_ID'])['INPUT'].transform(lambda x : ' '.join(map(str, x)))
data2['RESPONSE'] = data2.groupby(['IVA_CHAT_ID'])['RESPONSE'].transform(lambda x : ' '.join(map(str, x)))
data2 = data2[['IVA_CHAT_ID','DATE_TIME','END_DATE_TIME','CHAT_TYPE','CLIENT_ID','IVA_CHAT_REASON','INPUT','RESPONSE']]
data2 = data2.drop_duplicates()  
data3['DATE_TIME'] = data3.groupby(['IVA_CHAT_ID'])['DATE_TIME'].transform(lambda x : ",".join(map(str, x)))
data3['END_DATE_TIME'] = data3.groupby(['IVA_CHAT_ID'])['END_DATE_TIME'].transform(lambda x : ' '.join(map(str, x)))
data3['CHAT_TYPE'] = data3.groupby(['IVA_CHAT_ID'])['CHAT_TYPE'].transform(lambda x : ' '.join(map(str, x)))
data3['CLIENT_ID'] = data3.groupby(['IVA_CHAT_ID'])['CLIENT_ID'].transform(lambda x : ' '.join(map(str, x)))
data3['IVA_CHAT_REASON'] = data3.groupby(['IVA_CHAT_ID'])['IVA_CHAT_REASON'].transform(lambda x : ' '.join(map(str, x)))
data3['INPUT'] = data3.groupby(['IVA_CHAT_ID'])['INPUT'].transform(lambda x : ' '.join(map(str, x)))
data3['RESPONSE'] = data3.groupby(['IVA_CHAT_ID'])['RESPONSE'].transform(lambda x : ' '.join(map(str, x)))
data3 = data3[['IVA_CHAT_ID','DATE_TIME','END_DATE_TIME','CHAT_TYPE','CLIENT_ID','IVA_CHAT_REASON','INPUT','RESPONSE']]
data3 = data3.drop_duplicates()  
data4['DATE_TIME'] = data4.groupby(['IVA_CHAT_ID'])['DATE_TIME'].transform(lambda x : ",".join(map(str, x)))
data4['END_DATE_TIME'] = data4.groupby(['IVA_CHAT_ID'])['END_DATE_TIME'].transform(lambda x : ' '.join(map(str, x)))
data4['CHAT_TYPE'] = data4.groupby(['IVA_CHAT_ID'])['CHAT_TYPE'].transform(lambda x : ' '.join(map(str, x)))
data4['CLIENT_ID'] = data4.groupby(['IVA_CHAT_ID'])['CLIENT_ID'].transform(lambda x : ' '.join(map(str, x)))
data4['IVA_CHAT_REASON'] = data4.groupby(['IVA_CHAT_ID'])['IVA_CHAT_REASON'].transform(lambda x : ' '.join(map(str, x)))
data4['INPUT'] = data4.groupby(['IVA_CHAT_ID'])['INPUT'].transform(lambda x : ' '.join(map(str, x)))
data4['RESPONSE'] = data4.groupby(['IVA_CHAT_ID'])['RESPONSE'].transform(lambda x : ' '.join(map(str, x)))
data4 = data4[['IVA_CHAT_ID','DATE_TIME','END_DATE_TIME','CHAT_TYPE','CLIENT_ID','IVA_CHAT_REASON','INPUT','RESPONSE']]
data4 = data4.drop_duplicates()
data_merged = pd.concat([data1, data2, data3, data4])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_merged = pd.merge(data_merged, time_data, how='inner',on='IVA_CHAT_ID')

# %%
# load libraries
import re
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
import nltk
nltk.download('omw-1.4')
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk.stem import WordNetLemmatizer

stopwords = stopwords.words('english')
data_merged['tokenized_input'] = data_merged.apply(lambda row: nltk.word_tokenize(row['INPUT']), axis=1)
data_merged
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ...

# %%
def remove_stopwords(token_sentence):
    clean_tokens = [w.lower() for w in token_sentence if not w in stopwords]  
    return clean_tokens
    
data_merged['stopremoved_input'] = data_merged['tokenized_input'].apply(remove_stopwords)

data_merged
# Out:
#         IVA_CHAT_ID  ...                                  stopremoved_input
# 0          93971305  ...  [way, modify, amount, auto, pay, without, canc...
# 1          74003553  ...  [made, purchase, kayak, card, n't, see, histor...
# 2          93971311  ...                                  [change, address]
# 3          74003560  ...                    [report, account, lost, stolen]
# 4          74003559  ...  [start, :, credit, limit, increase, request, i...
# ...             ...  ...                                                ...
# 195855     94277650  ...  [number, call, customer, service, old, navy, v...
# 195856     74303822  ...  [billing, due, date, contact, us, phone, need,...
# 195857     74303826  ...  [rewards, hi, got, mail, reward, 20, $, make, ...
# 195858     74303823  ...                         [yes, need, help, logging]
# 195859     74303824  ...  [hi, yes, need, make, payment, make, payment, ...
#
# [195860 rows x 18 columns]

# %%
# # Data Cleaning
# def clean(text):
# # Removes all special characters and numericals leaving the alphabets
#     text = re.sub('[^A-Za-z]+', ' ', text)
#     return text

# data1['Cleaned_input'] = data1['INPUT'].apply(clean)
# Tokenization, delete stop word, pos tag data
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(text)
    newlist = []
    for word, tag in tags:
        newlist.append(tuple([word, pos_dict.get(tag[0])]))
    return newlist
data_merged['Pos_tagged_input'] = data_merged['stopremoved_input'].apply(token_stop_pos)

# Lemmatization
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
        if not pos:
            lemma = word
            lemma_rew = lemma_rew + " " + lemma
        else:
            lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
            lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

data_merged['Lemma_input'] = data_merged['Pos_tagged_input'].apply(lemmatize)

# %%
data_merged = data_merged[~data_merged['Lemma_input'].str.contains('nan')]

# %%
# after P2: word cloud for representative chat
# Import all necesary libraries
import matplotlib.pyplot as plt
from wordcloud import  WordCloud, STOPWORDS, ImageColorGenerator
# Get stopwords from wordcloud library
stopwords = set(STOPWORDS)
# join all reviews
text = " ".join(chat for chat in data_merged.Lemma_input)
# Generate the image
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=100).generate(text)
 
# visualize the image
fig=plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Representative Chat Word Cloud')
plt.show()

# %%
#Vader algorithm
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sentiments = SentimentIntensityAnalyzer()
data_merged["vader_Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data_merged["Lemma_input"]]
data_merged["vader_Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data_merged["Lemma_input"]]
data_merged["vader_Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data_merged["Lemma_input"]]
# function to calculate vader sentiment
def vadersentimentanalysis(review):
    vs = sentiments.polarity_scores(review)
    return vs['compound']
data_merged['vader_Sentiment'] = data_merged['Lemma_input'].apply(vadersentimentanalysis)
def vader_analysis(compound):
    if compound >= 0.5:
        return 'Positive'
    elif compound <= -0.5:
        return 'Negative'
    else:
        return 'Neutral'
data_merged['vader_Analysis'] = data_merged['vader_Sentiment'].apply(vader_analysis)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# ...

# %%
# TextBlob algorithm
from textblob import TextBlob
# function to calculate subjectivity
def getSubjectivity(review):
    return TextBlob(review).sentiment.subjectivity
    # function to calculate polarity
def getPolarity(review):
    return TextBlob(review).sentiment.polarity

# function to analyze the reviews
def analysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

data_merged['Blob_Subjectivity'] = data_merged['Lemma_input'].apply(getSubjectivity) 
data_merged['Blob_Polarity'] = data_merged['Lemma_input'].apply(getPolarity) 
data_merged['Blob_Analysis'] = data_merged['Blob_Polarity'].apply(analysis)
# tb_counts = data_merged.Blob_Analysis.value_counts()
# tb_counts
data_merged[data_merged['Blob_Analysis'] == 'Negative']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Sentiment Analysis using SentiWordNet
nltk.download('sentiwordnet')
from nltk.corpus import sentiwordnet as swn
def sentiwordnetanalysis(pos_data):
    sentiment = 0
    tokens_count = 0
    for word, pos in pos_data:
        if not pos:
            continue
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        if not lemma:
            continue
        synsets = wordnet.synsets(lemma, pos=pos)
        if not synsets:
            continue
        # Take the first sense, the most common
        synset = synsets[0]
        swn_synset = swn.senti_synset(synset.name())
        sentiment += swn_synset.pos_score() - swn_synset.neg_score()
        tokens_count += 1
        # print(swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score())
        if not tokens_count:
            return 0
        if sentiment>0:
            return "Positive"
        if sentiment==0:
            return "Neutral"
        else:
            return "Negative"

data_merged['SWN_analysis'] = data_merged['Pos_tagged_input'].apply(sentiwordnetanalysis)
swn_counts = data_merged['SWN_analysis'].value_counts()
Blob_counts = data_merged['Blob_Analysis'].value_counts()
vader_counts = data_merged['vader_Analysis'].value_counts()
# Out:
# [nltk_data] Downloading package sentiwordnet to /root/nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Visualization of models development
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
plt.subplot(1,3,1)
plt.title("TextBlob results")
plt.pie(Blob_counts.values, labels = Blob_counts.index, explode = (0, 0, 0.25), autopct='%1.1f%%', shadow=False)
plt.subplot(1,3,2)
plt.title("VADER results")
plt.pie(vader_counts.values, labels = vader_counts.index, explode = (0, 0, 0.25), autopct='%1.1f%%', shadow=False)
plt.subplot(1,3,3)
plt.title("SentiWordNet results")
plt.pie(swn_counts.values, labels = swn_counts.index, explode = (0, 0, 0.25), autopct='%1.1f%%', shadow=False)
plt.show()

# %%
data_merged.to_csv("data_merged.csv")

# %%
# Word cloud for all sentiments and metric
fig = plt.figure(num=9, figsize=(12, 10))
for i, sentiment in enumerate(['Positive', 'Neutral', 'Negative']):
    if i == 1: i = 3
    elif i == 2: i = 6
     
    # join all reviews with 
    SWN_text = " ".join(review for review in data_merged[data_merged['SWN_analysis'] == sentiment].Lemma_input)
    vader_text = " ".join(review for review in data_merged[data_merged['vader_Analysis'] == sentiment].Lemma_input)
    Blob_text = " ".join(review for review in data_merged[data_merged['Blob_Analysis'] == sentiment].Lemma_input)

    SWN_wc = WordCloud(stopwords=stopwords, background_color="white", max_words=50).generate(SWN_text)
    vader_wc = WordCloud(stopwords=stopwords, background_color="white", max_words=50).generate(vader_text)
    Blob_wc = WordCloud(stopwords=stopwords, background_color="white", max_words=50).generate(Blob_text)

    fig.add_subplot(3, 3, i + 1)
    plt.imshow(SWN_wc, interpolation='bilinear', alpha=1)
    plt.axis("off")
    plt.title('SentiWorldNet' + sentiment)
     
    fig.add_subplot(3, 3, i + 2)
    plt.imshow(vader_wc, interpolation='bilinear')
    plt.axis("off")
    plt.title('Vader' + sentiment)
 
    fig.add_subplot(3, 3, i + 3)
    plt.imshow(Blob_wc, interpolation='bilinear')
    plt.axis("off")
    plt.title('TextBlob' + sentiment)
     
     
plt.show()

# %%
data_merged.to_csv("data_merged.csv")
